# %%
# !pip install -U imbalanced-learn
# Out:
# Looking in indexes: http://pypi.douban.com/simple
# Collecting imbalanced-learn
#   Downloading http://pypi.doubanio.com/packages/b1/bd/4bb46fb4d317fd0f19aa7463d8906598e5fee073c0842b57cb112f023a45/imbalanced_learn-0.8.1-py3-none-any.whl (189 kB)
# Requirement already satisfied: joblib>=0.11 in c:\python39\lib\site-packages (from imbalanced-learn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\python39\lib\site-packages (from imbalanced-learn) (1.6.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\python39\lib\site-packages (from imbalanced-learn) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.24 in c:\python39\lib\site-packages (from imbalanced-learn) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python39\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn) (2.1.0)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.8.1
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df=pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
x = df.iloc[:, 1:-1]
y = df.iloc[:, -1]

# %%
from imblearn.under_sampling import RandomUnderSampler

sampling_strategy = 0.8
rus = RandomUnderSampler(sampling_strategy=sampling_strategy)
X_res, y_res = rus.fit_resample(x, y)

# %%
y_res.value_counts()
# Out:
# 0    311
# 1    249
# Name: stroke, dtype: int64

# %%
X_res['stroke']=y_res

# %%
X_res
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 8744  Female  80.0             1              0          Yes  Self-employed
# 8745  Female  81.0             1              0          Yes  Self-employed
# 8746    Male  56.0             1              0          Yes        Private
# 8747  Female  77.0             0              0          Yes  Self-employed
# 8748    Male  57.0             0              0          Yes        Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             202.21   NaN     never smoked       1
# 2             Rural             105.92  32.5     never smoked       1
# 3             Urban             171.23  34.4           smokes       1
# 4             Rural             174.12  24.0     never smoked       1
# ...             ...                ...   ...              ...     ...
# 8744          Rural              72.67  28.9     never smoked       1
# 8745          Rural              74.02  25.0     never smoked       1
# 8746          Rural             249.31  35.8     never smoked       1
# 8747          Rural              90.00  32.0     never smoked       1
# 8748          Rural              84.96  36.7          Unknown       1
#
# [8749 rows x 11 columns]

# %%
X_res.to_csv('under_sample.csv', index=False)

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(sampling_strategy=sampling_strategy)
X_res, y_res = ros.fit_resample(x, y)

# %%
X_res['stroke']=y_res

# %%
X_res.to_csv('over_sample.csv', index=False)
